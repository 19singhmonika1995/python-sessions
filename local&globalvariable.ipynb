# %% [markdown]
# LOCAL VARIABLE***********

# %%
def avg():
    num1= 20
    num2= 30
    num3= 40
    avg= (num1+num2+num3)/3
    print("the avg of {},{} is {}".format(num1,num2,num3,add))

avg()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5     avg= (num1+num2+num3)/3
#       6     print("the avg of {},{} is {}".format(num1,num2,num3,add))
# ----> 8 avg()
#
# Cell In[1], line 6, in avg()
#       4 num3= 40
#       5 avg= (num1+num2+num3)/3
# ----> 6 print("the avg of {},{} is {}".format(num1,num2,num3,add))
#
# NameError: name 'add' is not defined

# %% [markdown]
# GLOBAL VARIABLE**********

# %%
num1= 20
num2= 30
num3= 40
def avg():
    avg= (num1+num2+num3)/3
    print("the avg of {},{} is {}".format(num1,num2,num3,add))

avg()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       5     avg= (num1+num2+num3)/3
#       6     print("the avg of {},{} is {}".format(num1,num2,num3,add))
# ----> 8 avg()
#
# Cell In[3], line 6, in avg()
#       4 def avg():
#       5     avg= (num1+num2+num3)/3
# ----> 6     print("the avg of {},{} is {}".format(num1,num2,num3,add))
#
# NameError: name 'add' is not defined

# %%
def average():
    num1= 20
    num2= 30
    num3= 40
    average=(num1+num2+num3)/3

    print("the average of {}, {}, {} is {}:".format(num1,num2,num3,average))

average()
# Out:
# the average of 20, 30, 40 is 30.0:

# %%
def average():
    num11= 20
    num22= 30
    num33= 40
    average=(num11+num22+num33)/3

    print("the average of {}, {}, {} is {}:".format(num11,num22,num33,average))
    return(num11)

num11=average()
# Out:
# the average of 20, 30, 40 is 30.0:

# %%
def average():
    num11= 20
    num22= 30
    num33= 40
    average=(num11+num22+num33)/3

    print("the average of {}, {}, {} is {}:".format(num11,num22,num33,average))
    return(num11,num22,num33)

val1,val2,val3=average()
# Out:
# the average of 20, 30, 40 is 30.0:

# %% [markdown]
# GLOBAL VARIABLE

# %%
num11= 20
num22= 30
num33= 40
def average():            
    average=(num11+num22+num33)/3
    print("the average of {}, {}, {} is {}:".format(num11,num22,num33,average))

average()
# Out:
# the average of 20, 30, 40 is 30.0:

# %%
n1=20
n2=30
def addition():
    n1=200
    n2=300
    add= n1+n2
    print("the addition of {}, {}, {} is {}:".format(num1,num2,add))

addition()
print(n1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 9
#       6     add= n1+n2
#       7     print("the addition of {}, {}, {} is {}:".format(num1,num2,add))
# ----> 9 addition()
#      10 print(n1)
#
# Cell In[11], line 7, in addition()
#       5 n2=300
#       6 add= n1+n2
# ----> 7 print("the addition of {}, {}, {} is {}:".format(num1,num2,add))
#
# IndexError: Replacement index 3 out of range for positional args tuple

# %%
n1=20
n2=30
def addition(n1):
    n2=300
    add= n1+n2
    print("the addition of {}, {}, {} is {}:".format(num1,num2,add))

addition(500)
print(n1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 8
#       5     add= n1+n2
#       6     print("the addition of {}, {}, {} is {}:".format(num1,num2,add))
# ----> 8 addition(500)
#       9 print(n1)
#
# Cell In[12], line 6, in addition(n1)
#       4 n2=300
#       5 add= n1+n2
# ----> 6 print("the addition of {}, {}, {} is {}:".format(num1,num2,add))
#
# IndexError: Replacement index 3 out of range for positional args tuple

# %%
n1=20
n2=30
def addition(n1=700):
    n2=300
    add= n1+n2
    print("the addition of {}, {}, {} is {}:".format(num1,num2,add))

addition(500)
print(n1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 8
#       5     add= n1+n2
#       6     print("the addition of {}, {}, {} is {}:".format(num1,num2,add))
# ----> 8 addition(500)
#       9 print(n1)
#
# Cell In[13], line 6, in addition(n1)
#       4 n2=300
#       5 add= n1+n2
# ----> 6 print("the addition of {}, {}, {} is {}:".format(num1,num2,add))
#
# IndexError: Replacement index 3 out of range for positional args tuple

# %%
def numbers():
    num1= eval(input("enter 1st num"))
    num2= eval(input("enter 2nd num"))
    num3= eval(input("enter 3rd num"))
    if num2<num1>num3:
        print(num1, "is the greatest number")
        a=num1
    elif num2>num3:
        print(num2, "is the greatest number")
    else:
        print(num3, "is the greatest number")
        a=num3
    return(a)

a= numbers()

# %% [markdown]
# GLOBAL

# %%
n1=10
def updated():
    n1=n1+100
    print("n1 value inside function is:",n1)

updated()
print(n1)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[15], line 6
#       3     n1=n1+100
#       4     print("n1 value inside function is:",n1)
# ----> 6 updated()
#       7 print(n1)
#
# Cell In[15], line 3, in updated()
#       2 def updated():
# ----> 3     n1=n1+100
#       4     print("n1 value inside function is:",n1)
#
# UnboundLocalError: cannot access local variable 'n1' where it is not associated with a value

# %%
def value():
    num= 10
    print(num1)

value()
print(num1)
# Out:
# 20
# 20

# %%
def value():
    global num1,num2
    num= 10
    num2= 20

value()
print(num1)
print(num2)

value()
print(num1)
# Out:
# 20
# 20
# 20

# %%
n_=10
def updated():
    global n_
n_=20
n_=n_+100
print("n1 value inside function is:",n_)

updated()
print(n_)
# Out:
# n1 value inside function is: 120
# 120

# %%
n1=20
n2=30
def addition(n1):
    global n2, add
    n2=300
    add= n1+n2
    print("the addition of {}, {}, {} is {}:".format(n1,n2,add))

addition(500)
print(n2)
print(add)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 9
#       6     add= n1+n2
#       7     print("the addition of {}, {}, {} is {}:".format(n1,n2,add))
# ----> 9 addition(500)
#      10 print(n2)
#      11 print(add)
#
# Cell In[22], line 7, in addition(n1)
#       5 n2=300
#       6 add= n1+n2
# ----> 7 print("the addition of {}, {}, {} is {}:".format(n1,n2,add))
#
# IndexError: Replacement index 3 out of range for positional args tuple

# %% [markdown]
# FUNCTION IN FUNCTION********

# %%
def greet():
    print("hello")

def name():
    print("python")

greet()
name()
# Out:
# hello
# python

# %%
def greet():
    print("hello")

def name():
    print("python")
    greet()

name()
# Out:
# python
# hello

# %%
def greet():
    print("hello")
    name()
    
def name():
    print("python")

greet()
# Out:
# hello
# python

# %%
def greet():
    print("hello")
    name()
    
def name():
    print("python")
    greet()
    
greet()
name()
# Out:
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# python
# hello
# ...

# %%
print(3)

    def fun1():
        print('hello')
        print('python')

    print('10+10')
    def fun2():
        print('3+5')
        print(3+5)
        fun1()
        print('good')

    print(10+10)
    def fun3():
        fun1()
        fun2()

fun3()
# Out:
#   Cell In[28], line 3
#     def fun1():
#     ^
# IndentationError: unexpected indent

# %%
def add(a,b)
    print(a+b)
def sub(a,b)
    print(a-b)
def div(a,b)
    print(a/b)
def mul(a,b)
    print(a*b)

def main():
    num= eval(input("enter a num:"))
    a= eval(enter num1:")
    b= eval(enter num2:")

if num==1:
    add(a,b)
elif num==2:
    sub(a,b)
elif num==3:
    div(a,b)
else:
    mul(a,b)

main()
# Out:
#   Cell In[29], line 12
#     a= eval(enter num1:")
#                        ^
# SyntaxError: unterminated string literal (detected at line 12)
